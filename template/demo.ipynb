# %% [markdown]
# # Week XX – [Topic Title]
#
# > **Thursday Learning Hours · Session XX**
#
# ## Learning Objectives
# 1. ...
# 2. ...
# 3. ...

# %% [markdown]
# ## 0. Setup & Imports

# %%
# Add imports here

# %% [markdown]
# ## 1. Section Title

# %%
# Code for section 1

# %% [markdown]
# ## 2. Section Title

# %%
# Code for section 2

# %% [markdown]
# ## Summary & Key Takeaways
#
# - ...
# - ...
# - ...
#
# **Next session:** ...
